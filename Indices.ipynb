# %% [markdown]
# <a href="https://colab.research.google.com/github/San-Maansson/Stock_Analysis/blob/main/Indices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import yfinance as yf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#market_indices = pd.read_csv('market_indices.csv', index_col='Date')
#market_indices.head()

# %%
tickers= ['^GSPC','^IXIC','^DJI']
market_indices= pd.DataFrame()
for t in tickers:
    market_indices[t]= yf.download(t, start='2007-01-01', end = '2024-11-04')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
market_indices.head()
# Out:
#                                  ^GSPC        ^IXIC          ^DJI
# Date
# 2007-01-03 00:00:00+00:00  1416.599976  2423.159912  12474.519531
# 2007-01-04 00:00:00+00:00  1418.339966  2453.429932  12480.690430
# 2007-01-05 00:00:00+00:00  1409.709961  2434.250000  12398.009766
# 2007-01-08 00:00:00+00:00  1412.839966  2438.199951  12423.490234
# 2007-01-09 00:00:00+00:00  1412.109985  2443.830078  12416.599609

# %%
market_indices.tail()
# Out:
#                                  ^GSPC         ^IXIC          ^DJI
# Date
# 2024-10-28 00:00:00+00:00  5823.520020  18567.189453  42387.570312
# 2024-10-29 00:00:00+00:00  5832.919922  18712.750000  42233.050781
# 2024-10-30 00:00:00+00:00  5813.669922  18607.929688  42141.539062
# 2024-10-31 00:00:00+00:00  5705.450195  18095.150391  41763.460938
# 2024-11-01 00:00:00+00:00  5728.799805  18239.919922  42052.191406

# %%
#   S&P500 ^GSPC
#   Nasdaq Composite ^IXIC      (IT Companies)
#   Dow Jones Industrial Average ^DJI   (30 large public stocks)

# %%
(market_indices / market_indices.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
ind_returns = (market_indices / market_indices.shift(1)) - 1
ind_returns.tail()
# Out:
#                               ^GSPC     ^IXIC      ^DJI
# Date
# 2024-10-28 00:00:00+00:00  0.002651  0.002623  0.006486
# 2024-10-29 00:00:00+00:00  0.001614  0.007840 -0.003645
# 2024-10-30 00:00:00+00:00 -0.003300 -0.005602 -0.002167
# 2024-10-31 00:00:00+00:00 -0.018615 -0.027557 -0.008972
# 2024-11-01 00:00:00+00:00  0.004093  0.008000  0.006913

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC    0.097668
# ^IXIC    0.137255
# ^DJI     0.085358
# dtype: float64

# %%
# to obtain the annualized simple returns for the given indices:
(market_indices / market_indices.shift(1) - 1).mean() * 250
# Out:
# ^GSPC    0.097668
# ^IXIC    0.137255
# ^DJI     0.085358
# dtype: float64
